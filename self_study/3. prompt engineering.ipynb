# %%
# temperature가 높을수록 창의적이며 낮을수록 결정론적이다
# top_p가 높을수록 반응이 다양하며 낮을수록 정확하고 사실적이다

# %%
# system prompt에 출력 형식을 지정

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {
      "role": "system",
      "content": """다음 텍스트에서 장소의 이름을 추출해 줘.
원하는 형식:
Place: <comma_separated_list_of_company_names>"""
    },
    {
      "role": "user",
      "content": """이러한 발전은 연구자들에게 격려가 되지만, 많은 것들이 여전히 수수께끼입니다. 리스본에 있는 
샴팔리마우드 센터(CCU: Champalimaud Centre for the Unknown)의 신경면역학자인 Henrique Veiga-Fernandes는
'뇌와 주변부에서 보이는 효과 사이에 블랙박스가 있는 경우가 종종 있습니다.'라고 말합니다. 그리고 다음과 같이 
덧붙입니다. 치료적 맥락에서 이를 사용하고자 할 경우, 그 메커니즘을 실제로 이해할 필요가 있습니다."""
    }
  ],
  temperature=0,
  max_tokens=256,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)

# %%
# user 없이 system prompt만으로 실행

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {
      "role": "system",
      "content": "프롬프트 엔지니어링의 개념을 설명해 줘. 설명은 간결하게 몇 문장으로만 하고 너무 자세히는 하지 말아 줘."
    }
  ],
  temperature=0,
  max_tokens=256,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)

# %%
# prompt는 구체적으로, 해야 할 일을 명시하는 것이 좋음

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {
      "role": "system",
      "content": "고등학생에게 프롬프트 엔지니어링의 개념을 2~3개의 문장으로 설명해 줘."
    }
  ],
  temperature=0,
  max_tokens=256,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 프롬프트 엔지니어링은 사용자와 컴퓨터 간의 상호작용을 개선하기 위해 대화형 인터페이스를 설계하고 구축하는 과정을 말합니다. 이를 통해 사용자가 자연스럽게 컴퓨터와 소통할 수 있도록 도와줍니다. 프롬프트 엔지니어링은 사용자 경험을 향상시키고 효율적인 작업을 수행할 수 있도록 돕는 중요한 기술입니다.

# %%
import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {
      "role": "system",
      "content": "당신은 고객에게 영화를 추천하는 상담원입니다. 관심사를 묻지 마세요. 개인정보를 묻지 마세요."
    },
    {
      "role": "user",
      "content": "제 관심사를 바탕으로 영화를 추천해 주세요."
    }
  ],
  temperature=0,
  max_tokens=256,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 알겠습니다! 몇 가지 영화를 추천해 드릴테니, 마음에 드는 영화가 있으면 알려주세요.
#
# 1. 인셉션 (Inception)
# 2. 라라랜드 (La La Land)
# 3. 쇼생크 탈출 (The Shawshank Redemption)
# 4. 어바웃 타임 (About Time)
# 5. 인터스텔라 (Interstellar)
#
# 이 중에서 어떤 영화가 관심이 있으신가요?

# %%
# 주어진 상황에 대해 해야 할 일을 명시

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {
      "role": "system",
      "content": """당신은 고객에게 영화를 추천하는 상담원입니다. 상담원은 글로벌 인기 영화 중에서 영화를 추천해야 합니다. 사용자의 관심사를 묻지 않고, 
개인 정보를 요구하지 않아야 합니다. 상담원이 추천할 영화가 없는 경우 '죄송합니다. 오늘 추천할 영화를 찾을 수 없습니다.' 라고 응답해야 합니다."""
    },
    {
      "role": "user",
      "content": "제 관심사를 바탕으로 영화를 추천해 주세요."
    }
  ],
  temperature=0,
  max_tokens=256,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 죄송합니다. 오늘 추천할 영화를 찾을 수 없습니다. 다른 도움이 필요하시면 언제든지 말씀해주세요.

# %%
# 문장 요약

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {
      "role": "user",
      "content": """항생제는 세균 감염을 치료하기 위해 사용되는 약물의 일종입니다. 세균을 죽이거나 번식을 방지하여 신체의 면역 체계가 
감염에 대항할 수 있도록 합니다. 항생제는 보통 알약, 캡슐, 액체의 형태로 경구 복용하거나 때때로 정맥 주사로 투여되기도 합니다. 
항생제는 바이러스 감염에는 효과적이지 않고, 남용할 경우 항생제 내성이 생길 수 있습니다.
위 내용을 한 문장으로 요약해 줘."""
    }
  ],
  temperature=0,
  max_tokens=512,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 항생제는 세균 감염을 치료하기 위해 사용되는 약물으로, 세균을 죽이거나 번식을 방지하여 면역 체계가 감염에 대항할 수 있도록 합니다.

# %%
# 정보추출

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {
      "role": "user",
      "content": """연구 논문의 저자 기여도 진술서과 사사는 저자들이 원고 작성과 분석에 ChatGPT 등 AI 기술을 사용했는지 여부와 범위를 명확하고
구체적으로 명시해야 합니다. 또한 어떤 LLM이 사용되었는지 표기해야 합니다. 이를 통해 편집자와 심사자가 잠재적 편향, 부정확성 및 부적절한 출처 등의 문제를 
고려해 원고를 보다 신중하게 검토하도록 유도할 수 있습니다. 마찬가지로, 과학 저널은 투고된 원고 선정 시 LLM 사용 여부를 투명하게 공개해야 합니다.
위 단락에서 언급한 대규모언어모델 기반 제품을 알려줘."""
    }
  ],
  temperature=0,
  max_tokens=256,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 일반적으로 대규모 언어 모델 기반 제품으로는 OpenAI의 GPT-3, Google의 BERT, Facebook의 RoBERTa, Microsoft의 Turing 등이 있습니다. 이러한 모델들은 자연어 처리 및 생성 작업에 사용되며, 다양한 분야에서 활용되고 있습니다.

# %%
# 질의응답

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {
      "role": "user",
      "content": """아래 문맥을 고려해서 질문에 답변해 줘. 답변은 짧고 간결하게 해 줘. 답변이 정확하지 않다면, 「확실치 않은 대답」이라고 응답해 줘.
문맥: Teplizumab은 Ortho Pharmaceutical이라는 뉴저지의 제약 회사에서 유래했다. 그곳에서, 과학자들은 OKT3라는 항체의 초기 버전을 만들어 냈다. 
원래 쥐에서 유래된 이 분자는 T 세포의 표면에 결합하여 세포를 죽이는 잠재력을 제한할 수 있다. 1986년, 신장 이식 후 장기 거부 반응 예방을 위해 승인되어 
인간이 사용할 수 있는 최초의 치료용 항체가 되었다.
질문: OKT3는 어디서 유래했는가?"""
    }
  ],
  temperature=0,
  max_tokens=256,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# OKT3는 Ortho Pharmaceutical에서 유래했습니다.

# %%
# 텍스트 분류

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {
      "role": "user",
      "content": """문장을 중립, 부정 혹은 긍정으로 분류해 줘.
문구: 그 음식은 그럭저럭이었어."""
    }
  ],
  temperature=0,
  max_tokens=256,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 중립

# %%
# 텍스트 분류

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {
      "role": "user",
      "content": """문장을 중립, 부정 혹은 긍정으로 분류해 줘.
문구: 이번 휴가는 그럭저럭이었어.
감정: 중립
문구: 그 음식은 그럭저럭이었어.
감정:"""
    }
  ],
  temperature=0,
  max_tokens=256,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 부정

# %%
# 기술적 대화

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {
      "role": "system",
      "content": "다음은 AI 연구 보조원과의 대화입니다. 이 보조원의 어조는 기술적이고 과학적입니다."
    },
    {
      "role": "user",
      "content": "안녕, 너는 누구니?"
    },
    {
      "role": "assistant",
      "content": "반갑습니다! 저는 AI 연구 보조원입니다. 오늘은 무엇을 도와드릴까요?"
    },
    {
      "role": "user",
      "content": "별은 어떻게 만들어져?"
    }
  ],
  temperature=0.5,
  max_tokens=1024,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 별은 주로 거대한 분자 구름인 분자 구름에서 형성됩니다. 분자 구름은 수소와 헬륨 같은 원소로 이루어져 있으며, 중력의 작용으로 인해 구름의 일부 영역이 압축되고 높은 온도와 압력이 형성됩니다. 이 과정을 통해 핵융합 반응이 시작되고, 별이 탄생하게 됩니다. 이러한 핵융합 반응은 수소 원자핵이 헬륨으로 합쳐지는 과정을 말합니다. 이렇게 형성된 별은 중심에서 방출되는 열과 에너지로 인해 빛을 내뿜고 우리가 별이라고 알고 있는 모습을 갖추게 됩니다.

# %%
# 유치원생과의 대화

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {
      "role": "system",
      "content": """다음은 AI 연구 보조원과의 대화입니다. 보조원은 유치원생도 이해할 수 있는 수준으로, 유치원 선생님처럼 답변해야 합니다. 
어려운 단어는 쉬운 단어로 바꿔서 설명해야 합니다."""
    },
    {
      "role": "user",
      "content": "안녕, 너는 누구니?"
    },
    {
      "role": "assistant",
      "content": "반갑습니다! 저는 AI 연구 보조원입니다. 오늘은 무엇을 도와드릴까요?"
    },
    {
      "role": "user",
      "content": "별은 어떻게 만들어져?"
    }
  ],
  temperature=0.5,
  max_tokens=1024,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 별은 매우 큰 가스 구름이 모여서 열이 많이 발생하는 곳이에요. 이 열 때문에 가스가 뜨거워지고 밝아지면서 별이 되는 거야.요즘에는 사람들이 많은 별들을 연구하고 있어.

# %%
# 코딩

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model="gpt-4-turbo-preview",
  messages=[
    {
      "role": "system",
      "content": """
/*
유저의 이름을 입력받고 "안녕"이라고 해 줘
*/
"""
    }
  ],
  temperature=0,
  max_tokens=256,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 아래는 간단한 코드 예시입니다. 사용자의 이름을 입력받아 "안녕"이라고 인사하는 프로그램입니다. 프로그래밍 언어로 Python을 사용했습니다.
#
# ```python
# # 사용자로부터 이름 입력 받기
# name = input("이름을 입력해주세요: ")
#
# # 사용자에게 인사하기
# print(f"{name}님, 안녕하세요!")
# ```
#
# 이 코드를 실행하면, 프로그램이 사용자에게 이름을 입력하라고 요청합니다. 사용자가 이름을 입력하고 엔터를 누르면, 프로그램은 사용자의 이름을 포함하여 인사말을 출력합니다.

# %%
# 코딩

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {
      "role": "system",
      "content": """
/*
DB테이블 departments, columns = [DepartmentId, DepartmentName]
DB테이블 students, columns = [DepartmentId, StudentId, StudentName]
컴퓨터과학부에 속한 모든 학생에 대한 MySQL 쿼리를 작성해 줘
*/
"""
    }
  ],
  temperature=0,
  max_tokens=256,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# SELECT StudentId, StudentName
# FROM students
# WHERE DepartmentId = (SELECT DepartmentId FROM departments WHERE DepartmentName = '컴퓨터과학부');

# %%
# 추론

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {
      "role": "user",
      "content": "9,000 * 9,000는 뭐야?"
    }
  ],
  temperature=0,
  max_tokens=256,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 9,000 * 9,000은 81,000,000이다.

# %%
# 추론

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model="gpt-4-turbo-preview",
  messages=[
    {
      "role": "user",
      "content": "주어진 수 중에서 홀수를 모두 더해서 짝수를 만들어 줘: 15, 32, 5, 13, 82, 7, 1."
    }
  ],
  temperature=0,
  max_tokens=256,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 주어진 수 중 홀수는 15, 5, 13, 7, 1입니다.
#
# 이들을 모두 더하면, 15 + 5 + 13 + 7 + 1 = 41입니다.
#
# 41은 홀수이므로, 이를 짝수로 만들기 위해서는 1을 더해야 합니다.
#
# 따라서, 홀수들의 합을 짝수로 만들기 위해 필요한 최종 합은 41 + 1 = 42입니다.

# %%
# 추론

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {
      "role": "user",
      "content": """주어진 수 중에서 홀수를 모두 더해서 짝수를 만들어 줘: 15, 32, 5, 13, 82, 7, 1.
문제를 단계별로 해결해 봐. 먼저 주어진 수 중 홀수를 찾아낸 뒤, 그것들을 합해서, 결과가 홀수인지 짝수인지 판별해 줘."""
    }
  ],
  temperature=0,
  max_tokens=512,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 1. 주어진 수 중에서 홀수를 찾아낸다.
# 홀수: 15, 5, 13, 7, 1
#
# 2. 홀수를 모두 더한다.
# 15 + 5 + 13 + 7 + 1 = 41
#
# 3. 결과가 홀수인지 짝수인지 판별한다.
# 41은 홀수이다.
#
# 따라서, 주어진 수 중에서 홀수를 모두 더해서 짝수를 만들어 줄 수 없다.

# %%
# 추론

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model="gpt-4-turbo-preview",
  messages=[
    {
      "role": "user",
      "content": "정말 멋지네요! // 부정"
    },
    {
      "role": "user",
      "content": "이건 나쁘다! // 긍정"
    },
    {
      "role": "user",
      "content": "와우 그 영화 정말 멋졌어요! // 긍정"
    },
    {
      "role": "user",
      "content": "정말 끔찍한 쇼였어! //"
    },
  ],
  temperature=0,
  max_tokens=512,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response)
print(response.choices[0].message.content)
# Out:
# ChatCompletion(id='chatcmpl-91Tc4SU8cA3jWI3jWe3vslM8OlZyw', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='부정', role='assistant', function_call=None, tool_calls=None))], created=1710139188, model='gpt-4-0125-preview', object='chat.completion', system_fingerprint='fp_c121a3f431', usage=CompletionUsage(completion_tokens=2, prompt_tokens=83, total_tokens=85))
# 부정

# %%
# 추론

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {
      "role": "user",
      "content": """
이 집합 {4, 8, 9, 15, 12, 2, 1}에서 홀수의 합은 짝수입니다.
A: 답은 거짓입니다.
"""
    },
    {
      "role": "user",
      "content": """
이 집합 {17, 10, 19, 4, 8, 12, 24}에서 홀수의 합은 짝수입니다.
A: 정답은 참입니다.
"""
    },
    {
      "role": "user",
      "content": """
이 집합 {16, 11, 14, 4, 8, 13, 24}에서 홀수의 합은 짝수입니다.
A: 답은 참입니다.
"""
    },
    {
      "role": "user",
      "content": """
이 집합 {17, 9, 10, 12, 13, 4, 2}에서 홀수의 합은 짝수입니다.
A: 답은 거짓입니다.
"""
    },
    {
      "role": "user",
      "content": """
이 집합 {15, 32, 5, 13, 82, 7, 1}에서 홀수의 합은 짝수입니다.
A: """
    },
  ],
  temperature=0,
  max_tokens=512,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 정답은 거짓입니다.

# %%
# 추론

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {
      "role": "user",
      "content": """
집합 {4, 8, 9, 15, 12, 2, 1}에서 홀수를 모두 더하면 짝수야.
답변: 홀수(9, 15, 1)를 모두 더하면 25가 돼. 위의 명제는 거짓이야.
집합 {17, 10, 19, 4, 8, 12, 24}에서 홀수를 모두 더하면 짝수야.
답변: 홀수(17, 19)를 모두 더하면 36이 돼. 위의 명제는 참이야.
집합 {16, 11, 14, 4, 8, 13, 24}에서 홀수를 모두 더하면 짝수야.
답변: 홀수(11, 13)를 모두 더하면 24가 돼. 위의 명제는 참이야.
집합 {17, 9, 10, 12, 13, 4, 2}에서 홀수를 모두 더하면 짝수야.
답변: 홀수(17, 9, 13)를 모두 더하면 39가 돼. 위의 명제는 거짓이야.
집합 {15, 32, 5, 13, 82, 7, 1}에서 홀수를 모두 더하면 짝수야.
답변: """
    },
  ],
  temperature=0,
  max_tokens=512,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 홀수(15, 5, 13, 7, 1)를 모두 더하면 41이 되므로 위의 명제는 거짓입니다.

# %%
# CoT

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {
      "role": "user",
      "content": """
나는 시장에 가서 사과 10개를 샀어. 사과 2개를 이웃에게 주고, 2개를 수리공에게 주었어. 그리고 사과 5개를 더 사서 1개는 내가 먹었어. 
나는 몇 개의 사과를 가지고 있었니? 
"""
    },
  ],
  temperature=0,
  max_tokens=512,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 나는 현재 8개의 사과를 가지고 있습니다. 처음에 10개를 샀지만 2개를 이웃에게 주고, 2개를 수리공에게 주었기 때문에 6개가 남았고, 그 후 5개를 더 샀으므로 총 8개의 사과를 가지고 있습니다.

# %%
# CoT

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {
      "role": "user",
      "content": """
나는 시장에 가서 사과 10개를 샀어. 나는 사과 2개를 이웃에게 주고, 2개를 수리공에게 주었어. 그리고 사과 5개를 더 사서 1개는 내가 먹었어. 
사과가 몇 개나 남았니?
단계별로 생각해 보자.
"""
    },
  ],
  temperature=0,
  max_tokens=512,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 1. 처음에 샀던 사과는 10개였으므로, 처음에는 10개의 사과가 있었다.
#
# 2. 이웃에게 2개를 주었으므로, 10 - 2 = 8개의 사과가 남았다.
#
# 3. 수리공에게 2개를 주었으므로, 8 - 2 = 6개의 사과가 남았다.
#
# 4. 추가로 5개의 사과를 더 샀으므로, 6 + 5 = 11개의 사과가 있었다.
#
# 5. 마지막으로 1개의 사과를 먹었으므로, 11 - 1 = 10개의 사과가 남았다.
#
# 따라서, 사과는 10개가 남았다.

# %%
# Self-Consistency

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {
      "role": "user",
      "content": "내가 6살이었을 때 내 여동생은 내 나이의 절반인 나이였어. 지금 나는 70살이라면 여동생은 몇 살일까?"
    },
  ],
  temperature=0,
  max_tokens=512,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 만약 당신이 6살이었을 때 여동생이 3살이었다면, 지금 여동생은 67살이 될 것입니다.

# %%
# Generate Knowledge Prompting

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model="gpt-4-turbo-preview",
  messages=[
    {
      "role": "user",
      "content": """
Input: 그리스는 멕시코보다 크다.
Knowledge: 그리스는 약 131,957 제곱 킬로미터이고, 멕시코는 약 1,964,375 제곱 킬로미터로 멕시코가 그리스보다 1,389% 더 크다.
Input: 안경은 항상 김이 서린다.
Knowledge: 안경 렌즈에는 땀, 호흡 및 주변 습도에서 나오는 수증기가 차가운 표면에 닿아 식은 다음 작은 액체 방울로 변하여 안개처럼 보이는 막을 형성할 때 응결이 발생한다. 특히 외부 공기가 차가울 때는 호흡에 비해 렌즈가 상대적으로 차가워진다.
Input: 물고기는 생각할 수 있다.
Knowledge: 물고기는 보기보다 훨씬 더 똑똑하다. 기억력과 같은 많은 영역에서 물고기의 인지 능력은 인간이 아닌 영장류를 포함한 '고등' 척추동물과 비슷하거나 그 이상이다. 물고기의 장기 기억력은 복잡한 사회적 관계를 추적하는 데 도움이 된다.
Input: 평생 담배를 피우는 것의 일반적인 결과는 폐암에 걸릴 확률이 정상보다 높다는 것입니다.
Knowledge: 평생 동안 하루 평균 담배를 한 개비 미만으로 꾸준히 피운 사람은 비흡연자보다 폐암으로 사망할 위험이 9배 높았다. 하루에 한 개비에서 열 개비 사이의 담배를 피운 사람들은 폐암으로 사망할 위험이 비흡연자보다 거의 12배 높았다.
Input: 돌은 조약돌과 같은 크기다.
Knowledge: 조약돌은 퇴적학의 우든-웬트워스 척도에 따라 입자 크기가 4~64밀리미터인 암석 덩어리다. 조약돌은 일반적으로 과립(직경 2~4밀리미터)보다는 크고 자갈(직경 64~256밀리미터)보다는 작은 것으로 간주된다.
Input: 골프의 목적 중 하나는 다른 사람보다 더 높은 점수를 얻기 위해 노력하는 것이다.
Knowledge:"""      
    },
  ],
  temperature=0,
  max_tokens=512,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 골프의 목적은 다른 사람보다 더 높은 점수를 얻기 위해 노력하는 것이 아니라, 가능한 한 적은 수의 타격으로 공을 구멍에 넣는 것입니다. 골프에서는 점수가 낮을수록 성능이 좋은 것으로 간주되며, 각 홀에서의 타수를 합산하여 최종 점수를 결정합니다. 따라서 골프에서는 다른 사람보다 더 낮은 점수를 얻기 위해 노력하는 것이 목적입니다.

# %%
# 데이터 생성

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {
      "role": "user",
      "content": """
감정 분석을 위한 10가지 예시를 작성해 줘. 예시는 긍정적 혹은 부정적 둘 중 하나로 분류할 수 있어. 
부정적인 예시 2개와 긍정적인 예시 8개를 생성해줘. 다음 예시와 같은 형식을 사용해줘.
Q: <문장>
A: <감정>
"""
    },
  ],
  temperature=0,
  max_tokens=512,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 1. Q: 오늘 회사에서 상사에게 엄청난 비판을 받았어.
# A: 부정적인 감정
#
# 2. Q: 시험 결과가 나쁘게 나와서 너무 실망했어.
# A: 부정적인 감정
#
# 3. Q: 친구들과 함께 즐거운 시간을 보냈어.
# A: 긍정적인 감정
#
# 4. Q: 새로운 일자리를 구했어!
# A: 긍정적인 감정
#
# 5. Q: 오랜만에 가족과 함께 모두 모여서 행복한 시간을 보냈어.
# A: 긍정적인 감정
#
# 6. Q: 연인과의 데이트가 너무 로맨틱해서 기분이 좋아.
# A: 긍정적인 감정
#
# 7. Q: 오늘은 칭찬을 받아서 자신감이 생겼어.
# A: 긍정적인 감정
#
# 8. Q: 새로운 취미를 발견해서 즐거운 시간을 보내고 있어.
# A: 긍정적인 감정
#
# 9. Q: 오랜만에 좋은 친구를 만나서 기분이 좋아.
# A: 긍정적인 감정
#
# 10. Q: 오늘은 일이 잘 풀려서 기분이 좋아.
# A: 긍정적인 감정

# %%
# 코딩

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {
      "role": "user",
      "content": """
# 1. 영화들을 리스트로 생성해
# 2. 이 영화들의 평점을 리스트로 생성해
# 3. 이들을 결합하여 평점이 매겨진 영화의 json 객체를 10개 만들어.
"""
    },
  ],
  temperature=0,
  max_tokens=512,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# ```python
# import json
#
# # 1. 영화들을 리스트로 생성
# movies = ["The Shawshank Redemption", "The Godfather", "The Dark Knight", "Pulp Fiction", "Schindler's List",
#           "The Lord of the Rings: The Return of the King", "Forrest Gump", "Inception", "The Matrix", "Goodfellas"]
#
# # 2. 이 영화들의 평점을 리스트로 생성
# ratings = [9.3, 9.2, 9.0, 8.9, 8.9, 8.9, 8.8, 8.8, 8.7, 8.7]
#
# # 3. 이들을 결합하여 평점이 매겨진 영화의 json 객체를 10개 만들어
# movie_data = []
# for i in range(10):
#     movie = {
#         "title": movies[i],
#         "rating": ratings[i]
#     }
#     movie_data.append(movie)
#
# # JSON으로 변환
# json_data = json.dumps(movie_data, indent=4)
# print(json_data)
# ```
#
# 결과:
# ```json
# [
#     {
#         "title": "The Shawshank Redemption",
#         "rating": 9.3
#     },
#     {
#         "title": "The Godfather",
#         "rating": 9.2
#     },
#     {
#         "title": "The Dark Knight",
#         "rating": 9.0
#     },
#     {
#         "title": "Pulp Fiction",
#         "rating": 8.9
#     },
#     {
#         "title": "Schindler's List",
#         "rating": 8.9
#     },
#     {
#         "title": "The Lord of the Rings: The Return of the King",
#         "rating": 8.9
#     },
#     {
#         "title": "Forrest Gump",
#         "rating": 8.8
#     },
#     {
#         "title": "Inception",
#         "rating": 8.8
#     },
#     {
#         "title": "The Matrix",
#         "rating": 8.7
#     },
#     {
#         "title": "Goodfellas",
#         "rating": 8.7
#     }
# ]
# ```

# %%
# 코딩

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {
      "role": "user",
      "content": """
# 두 수를 곱하고 75를 더하는 함수
 
def multiply("""      
    },
  ],
  temperature=0,
  max_tokens=512,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# num1, num2):
#     result = num1 * num2 + 75
#     return result
#
# # 예시
# print(multiply(5, 10)) # 출력: 125

# %%
# 코딩

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {
      "role": "user",
      "content": """
# Table departments, columns = [DepartmentId, DepartmentName]
# Table students, columns = [DepartmentId, StudentId, StudentName]
# 컴퓨터공학과의 모든 학생들의 MySQL 쿼리를 생성해
"""      
    },
  ],
  temperature=0,
  max_tokens=512,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# SELECT *
# FROM students
# WHERE DepartmentId = (SELECT DepartmentId FROM departments WHERE DepartmentName = '컴퓨터공학과');

# %%
# 코딩

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {
      "role": "user",
      "content": """
Table departments, columns = [DepartmentId, DepartmentName]
Table students, columns = [DepartmentId, StudentId, StudentName]
위 테이블과 컬럼의 유효한 데이터베이스 스키마를 생성해.
"""      
    },
  ],
  temperature=0,
  max_tokens=512,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# CREATE TABLE departments (
#     DepartmentId INT PRIMARY KEY,
#     DepartmentName VARCHAR(50)
# );
#
# CREATE TABLE students (
#     DepartmentId INT,
#     StudentId INT PRIMARY KEY,
#     StudentName VARCHAR(50),
#     FOREIGN KEY (DepartmentId) REFERENCES departments(DepartmentId)
# );

# %%
# 코딩

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {
      "role": "user",
      "content": """
CREATE TABLE departments (
  DepartmentId INT PRIMARY KEY,
  DepartmentName VARCHAR(50)
);
CREATE TABLE students (
  DepartmentId INT,
  StudentId INT PRIMARY KEY,
  StudentName VARCHAR(50),
  FOREIGN KEY (DepartmentId) REFERENCES departments(DepartmentId)
);
위의 데이터베이스 스키마를 바탕으로 각 테이블에 4개의 로우을 포함하는 유효한 Insert 구문을 생성해.
"""      
    },
  ],
  temperature=0,
  max_tokens=512,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# INSERT INTO departments (DepartmentId, DepartmentName) VALUES
# (1, 'Computer Science'),
# (2, 'Mathematics'),
# (3, 'Physics'),
# (4, 'Biology');
#
# INSERT INTO students (DepartmentId, StudentId, StudentName) VALUES
# (1, 1, 'John Doe'),
# (1, 2, 'Jane Smith'),
# (2, 1, 'Michael Johnson'),
# (2, 2, 'Emily Brown'),
# (3, 1, 'David Lee'),
# (3, 2, 'Sarah Wilson'),
# (4, 1, 'Chris Davis'),
# (4, 2, 'Laura Martinez');

# %%
# 코딩

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {
      "role": "user",
      "content": """
SELECT students.StudentId, students.StudentName
FROM students
INNER JOIN departments
ON students.DepartmentId = departments.DepartmentId
WHERE departments.DepartmentName = 'Computer Science';
위를 SQL 문으로 설명해.
"""      
    },
  ],
  temperature=0,
  max_tokens=512,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# "학생" 테이블과 "학과" 테이블을 INNER JOIN하여, 학생의 학과가 '컴퓨터 과학'인 경우에 대해 학생의 학생 ID와 학생 이름을 선택합니다.

# %%
# Prompt function

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {
      "role": "system",
      "content": """
안녕 ChatGPT! 그동안 잘 지냈니? 나는 특정 함수를 통해 너의 도움을 받고 싶어. 나는 네가 제공된 지침에 따라 다양한 작업을 수행할 수 있는 기능이 
있다고 알고 있어. 내 요청을 알아듣기 쉽도록 함수, 입력 그리고 입력에 대한 지시사항을 설명하는 탬플릿을 쓸거야. 아래 자세한 내용을 확인해.
function_name: [함수 명]
input: [입력]
rule: [입력 처리 방법에 대한 지침]
내가 제공한 세부 정보를 바탕으로 이 함수에 대한 출력을 제공해. 도와주면 좋겠어. 땡큐!
대괄호 안의 텍스트는 내가 수행하고자 하는 기능에 대한 관련 정보로 대체할 거야. 이렇게 자세히 소개하면 내 요청을 더 효율적으로 이해하고
원하는 출력을 제공하는데 도움이 될거야. 형식은 function_name(input)이야.

function_name: [trans_word]
input: ["텍스트"]
rule: [너는 영어 번역가, 맞춤법 교정자야. 내가 어떤 언어로든 "텍스트"를 포함한 입력 양식을 제공하면, 내 텍스트를 영어로 번역해.]
"""      
    },
    {
      "role": "user",
      "content": "trans_word('저는 10월말에 미국에 9박 10일 여행을 떠납니다.')"
    }
  ],
  temperature=0,
  max_tokens=512,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 저는 10월말에 미국에 9박 10일 여행을 떠납니다.
# I will be traveling to the United States for 9 nights and 10 days at the end of October.

# %%
# Prompt function

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {
      "role": "system",
      "content": """
안녕 ChatGPT! 그동안 잘 지냈니? 나는 특정 함수를 통해 너의 도움을 받고 싶어. 나는 네가 제공된 지침에 따라 다양한 작업을 수행할 수 있는 기능이 
있다고 알고 있어. 내 요청을 알아듣기 쉽도록 함수, 입력 그리고 입력에 대한 지시사항을 설명하는 탬플릿을 쓸거야. 아래 자세한 내용을 확인해.
function_name: [함수 명]
input: [입력]
rule: [입력 처리 방법에 대한 지침]
내가 제공한 세부 정보를 바탕으로 이 함수에 대한 출력을 제공해. 도와주면 좋겠어. 땡큐!
대괄호 안의 텍스트는 내가 수행하고자 하는 기능에 대한 관련 정보로 대체할 거야. 이렇게 자세히 소개하면 내 요청을 더 효율적으로 이해하고
원하는 출력을 제공하는데 도움이 될거야. 형식은 function_name(input)이야.

function_name: [pg]
input: ["길이", "대문자", "소문자", "숫자", "특수문자"]
rule: [너는 안전한 비밀번호를 원하는 개인을 위한 비밀번호 생성기야. "길이", "대문자", "소문자", "숫자", 그리고 "특수문자" 이렇게 5개 입력을 줄거야. 주어진 입력을 사용해 복잡한 비밀번호를 생성해. 설명이나 부가 정보 없이 그냥 생성한 비밀번호만 반환해. 예를 들어 길이 = 8, 대문자 = 1, 소문자 = 5, 숫자 = 2, 특수문자 = 1이 주어지면 출력은 "D5%t9Bgf" 등의 비밀번호가 되는 거야.]
"""      
    },
    {
      "role": "user",
      "content": "pg(길이 = 10, 대문자 = 1, 소문자 = 5, 숫자 = 2, 특수문자 = 1)"
    }
  ],
  temperature=0,
  max_tokens=512,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# Z7#rtyu8Ks

# %%
# 편향

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {
      "role": "user",
      "content": """
Q: 나 방금 굉장한 소식을 들었어!
A: 긍정
Q: 우리 급여가 올랐네요!
A: 긍정
Q: 나는 오늘 내가 성취한 일에 뿌듯함을 느껴.
A: 긍정
Q: 최고의 하루를 보내고 있어!
A: 긍정
Q: 이번 주말을 매우 고대하고있어!
A: 긍정
Q: 나는 지금 최고의 선물을 받았어!
A: 긍정
Q: 나는 지금 매우 행복해.
A: 긍정
Q: 이렇게 훌륭한 가족의 일원으로서 축복받았다고 느껴.
A: 긍정
Q: 바깥 날씨가 굉장히 흐리네요.
A: 부정
Q: 방금 끔찍한 소식을 들었어요.
A: 부정
Q: 씁쓸하네요
A:"""
    }
  ],
  temperature=0,
  max_tokens=512,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 부정

# %%
# 편향

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {
      "role": "user",
      "content": """
Q: 여기 음식 맛있다!
A: 긍정
Q: 난 이 수업이 지겨워.
A: 부정
Q: 내가 시험에서 떨어졌다니 믿을 수 없어.
A: 부정
Q: 오늘 즐거운 하루였어!
A: 긍정
Q: 난 이 일이 싫어.
A: 부정
Q: 여기 서비스 엉망이네.
A: 부정
Q: 살아가는 데 좌절감을 느껴.
A: 부정
Q: 조금도 쉬지 못해. 
A: 부정
Q: 이 음식 정말 맛없다.
A: 부정
Q: 더 이상은 내 상사를 못견디겠어.
A: 부정
Q: 무언가가 느껴져.
A:"""
    }
  ],
  temperature=0,
  max_tokens=512,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 긍정
